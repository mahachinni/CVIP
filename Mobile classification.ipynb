# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =  pd.read_csv(r"C:\Users\mahal\Downloads\Datasets\archive (1)\test.csv")

# %%
data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
data.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
data.tail()
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
data.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
data.shape
# Out:
# (1000, 21)

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# # # Visualization on data

# %% [markdown]
# # # Let's plot some diagrams !!

# %%
sns.lineplot(data = data, x="px_height",y="px_width", ci = None)
# Out:
# <AxesSubplot:xlabel='px_height', ylabel='px_width'>

# %%
sns.lineplot(data = data, x = "battery_power", y = "ram", ci= None)
# Out:
# <AxesSubplot:xlabel='battery_power', ylabel='ram'>

# %%
sns.lineplot(data = data, x = "clock_speed", y = "m_dep", ci= None)
# Out:
# <AxesSubplot:xlabel='clock_speed', ylabel='m_dep'>

# %%
sns.lineplot(data = data, x = "dual_sim", y = "four_g", ci = None)
# Out:
# <AxesSubplot:xlabel='dual_sim', ylabel='four_g'>

# %% [markdown]
# # # Discover how much mobile has bluetooth or not

# %%
data['blue'].value_counts()
# Out:
# 1    516
# 0    484
# Name: blue, dtype: int64

# %%
plt.figure(figsize = (14,6))
sns.countplot(data = data, x = data['blue'])
# Out:
# <AxesSubplot:xlabel='blue', ylabel='count'>

# %%
data.corr()['clock_speed']
# Out:
# id               0.035917
# battery_power   -0.039075
# blue             0.034754
# clock_speed      1.000000
# dual_sim        -0.012423
# fc               0.010127
# four_g          -0.024665
# int_memory      -0.030487
# m_dep            0.016995
# mobile_wt       -0.014107
# n_cores         -0.012247
# pc               0.047469
# px_height        0.017277
# px_width         0.070585
# ram             -0.000650
# sc_h            -0.039503
# sc_w            -0.027138
# talk_time       -0.078797
# three_g         -0.021406
# touch_screen     0.061893
# wifi            -0.048593
# Name: clock_speed, dtype: float64

# %%
data.corr()
# Out:
#                      id  battery_power      blue  clock_speed  dual_sim  \
# id             1.000000      -0.021511  0.000464     0.035917 -0.002721
# battery_power -0.021511       1.000000 -0.046610    -0.039075 -0.061171
# blue           0.000464      -0.046610  1.000000     0.034754 -0.011100
# clock_speed    0.035917      -0.039075  0.034754     1.000000 -0.012423
# dual_sim      -0.002721      -0.061171 -0.011100    -0.012423  1.000000
# fc             0.016934      -0.007846 -0.056063     0.010127  0.057606
# four_g         0.030921      -0.042520 -0.001169    -0.024665  0.024907
# int_memory    -0.014023       0.003751 -0.012416    -0.030487 -0.012158
# m_dep         -0.002794      -0.009065  0.018319     0.016995  0.021760
# mobile_wt     -0.007541      -0.047065  0.023513    -0.014107 -0.001734
# n_cores       -0.015935       0.025732  0.003283    -0.012247 -0.003129
# pc             0.001969       0.012847 -0.025247     0.047469  0.073936
# ...

# %%
data.corr()[['blue','battery_power']]
# Out:
#                    blue  battery_power
# id             0.000464      -0.021511
# battery_power -0.046610       1.000000
# blue           1.000000      -0.046610
# clock_speed    0.034754      -0.039075
# dual_sim      -0.011100      -0.061171
# fc            -0.056063      -0.007846
# four_g        -0.001169      -0.042520
# int_memory    -0.012416       0.003751
# m_dep          0.018319      -0.009065
# mobile_wt      0.023513      -0.047065
# n_cores        0.003283       0.025732
# pc            -0.025247       0.012847
# px_height     -0.058810       0.048647
# px_width      -0.032054       0.053365
# ram            0.057570      -0.032366
# sc_h           0.012780      -0.055665
# sc_w           0.004223      -0.023905
# talk_time     -0.031995       0.015546
# three_g        0.013530       0.031514
# touch_screen  -0.060031      -0.010138
# wifi           0.025568      -0.000414

# %% [markdown]
# # Discover the Front Camera mega Pixels

# %%
data.fc.value_counts().head(10)
# Out:
# 0    210
# 1    124
# 2     97
# 4     80
# 5     74
# 3     70
# 6     59
# 7     50
# 9     41
# 8     38
# Name: fc, dtype: int64

# %%
plt.figure(figsize=(14,6))
data.fc.value_counts().head(10).plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## Correlations between features in out Training Data

# %%
sns.heatmap(data = data)
# Out:
# <AxesSubplot:>

# %%
 data.corr()
# Out:
#                      id  battery_power      blue  clock_speed  dual_sim  \
# id             1.000000      -0.021511  0.000464     0.035917 -0.002721
# battery_power -0.021511       1.000000 -0.046610    -0.039075 -0.061171
# blue           0.000464      -0.046610  1.000000     0.034754 -0.011100
# clock_speed    0.035917      -0.039075  0.034754     1.000000 -0.012423
# dual_sim      -0.002721      -0.061171 -0.011100    -0.012423  1.000000
# fc             0.016934      -0.007846 -0.056063     0.010127  0.057606
# four_g         0.030921      -0.042520 -0.001169    -0.024665  0.024907
# int_memory    -0.014023       0.003751 -0.012416    -0.030487 -0.012158
# m_dep         -0.002794      -0.009065  0.018319     0.016995  0.021760
# mobile_wt     -0.007541      -0.047065  0.023513    -0.014107 -0.001734
# n_cores       -0.015935       0.025732  0.003283    -0.012247 -0.003129
# pc             0.001969       0.012847 -0.025247     0.047469  0.073936
# ...

# %% [markdown]
# # Number of Cores of Processor

# %%
data['n_cores'].value_counts()
# Out:
# 4    142
# 1    138
# 2    134
# 5    130
# 3    127
# 8    121
# 7    107
# 6    101
# Name: n_cores, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='n_cores', y='battery_power', data = data)
# Out:
# <AxesSubplot:xlabel='n_cores', ylabel='battery_power'>

# %% [markdown]
# # Mobile Has 4G or Not

# %%
data.four_g.value_counts()
# Out:
# 0    513
# 1    487
# Name: four_g, dtype: int64

# %%
plt.figure(figsize=(14,6))
data.four_g.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Battery power

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data.battery_power)
# Out:
# C:\Users\mahal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='battery_power'>
